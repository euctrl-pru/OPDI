# %%
import pandas as pd

# %%
pd.read_csv('https://ourairports.com/data/airports.csv')
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 78321   46378  ZZ-0001       heliport            Sealand Helipad
# 78322  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 78323  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 78324  342102     ZZZW         closed     Scandium City Heliport
# 78325  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0       NaN          US
# ...
