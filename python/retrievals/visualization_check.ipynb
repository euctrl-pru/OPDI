# %%
import pandas as pd

# %%
pd.read_parquet('../../data/retrievals/*-to-LPPT/tracks_adep_*_ades_LPPT_2024-03-01.parquet')
# Out:
# Empty DataFrame
# Columns: [event_time, icao24, lat, lon, velocity, heading, vert_rate, callsign, on_ground, alert, spi, squawk, baro_altitude, geo_altitude, last_pos_update, last_contact, serials, track_id, h3_res_12, h3_res_11, h3_res_10, h3_res_9, h3_res_8, h3_res_7, h3_res_6, h3_res_5, h3_res_4, h3_res_3, h3_res_2, h3_res_1, h3_res_0, segment_distance_nm, cumulative_distance_nm]
# Index: []
#
# [0 rows x 33 columns]

# %%
pd.read_parquet('../../data/retrievals/*-to-EIDW/tracks_adep_*_ades_EIDW_2024-03-01.parquet')
# Out:
#      event_time  icao24        lat       lon   velocity     heading  \
# 0    1709251205  4ca2c9  53.412082 -6.103390  82.721571  275.710593
# 1    1709251210  4ca2c9  53.412501 -6.110256  81.647627  275.423219
# 2    1709251215  4ca2c9  53.412827 -6.116089  81.135501  275.457553
# 3    1709251220  4ca2c9  53.413147 -6.122445  79.551076  275.194429
# 4    1709251225  4ca2c9  53.413467 -6.128252  77.925956  274.543758
# ..          ...     ...        ...       ...        ...         ...
# 141  1709251910  4ca2c9  53.426914 -6.248082  76.900345  274.604487
# 142  1709251915  4ca2c9  53.426914 -6.248082  76.900345  274.604487
# 143  1709251920  4ca2c9  53.426914 -6.248082  76.900345  274.604487
# 144  1709251925  4ca2c9  53.426914 -6.248082  76.900345  274.604487
# 145  1709251930  4ca2c9  53.426914 -6.248082  76.900345  274.604487
#
#      vert_rate  callsign  on_ground  alert  ...         h3_res_7  \
# 0     -4.55168  EIN76HJ       False  False  ...  87182c8eeffffff
# ...
