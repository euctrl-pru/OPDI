# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import datetime
from pyspark.sql import Window, functions as F
import os

# Keys
minio_access_key = os.environ['OSN_USERNAME']
minio_secret_key = os.environ['OSN_KEY']

spark = SparkSession.builder.appName("MinioTest").getOrCreate()
sc = spark.sparkContext

spark.conf.set("spark.hadoop.fs.s3a.aws.credentials.provider", "com.amazonaws.auth.DefaultAWSCredentialsProviderChain")
spark.conf.set("spark.hadoop.fs.s3a.endpoint", "https://s3.opensky-network.org/")
spark.conf.set("spark.hadoop.fs.s3a.access.key", minio_access_key)
spark.conf.set("spark.hadoop.fs.s3a.secret.key", minio_secret_key)
spark.conf.set("spark.hadoop.fs.s3a.path.style.access", "true")
spark.conf.set("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
df = spark.read.parquet("s3a://ec-datadump/hour=2023-01-01/01", header=True)
# Out:
# Setting spark.hadoop.yarn.resourcemanager.principal to quinten.goens
# 25/03/31 08:35:10 ERROR common.DefaultRequestExecutor: [Thread-5]: Error executing request: org.apache.knox.gateway.shell.ErrorResponse: https://dl-live-ent-idbroker1.az-live.x9er-zkvz.cloudera.site:8444/gateway/aws-cab/cab/api/v1/credentials: HTTP/1.1 403 Forbidden
# 25/03/31 08:35:10 ERROR idbroker.AbstractIDBClient: [Thread-5]: Cloud Access Broker response: {
#   "error": "There is no mapped role for the group(s) associated with the authenticated user.",
#   "auth_id": "quinten.goens"
# }
#
# 25/03/31 08:35:10 ERROR common.DefaultRequestExecutor: [checkPathsExist-ForkJoinPool-2-worker-57]: Error executing request: org.apache.knox.gateway.shell.ErrorResponse: https://dl-live-ent-idbroker1.az-live.x9er-zkvz.cloudera.site:8444/gateway/aws-cab/cab/api/v1/credentials: HTTP/1.1 403 Forbidden
# ...

# %%
df.show()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit, to_date, from_unixtime
from datetime import datetime, date, timedelta
import subprocess
import os, shutil, time
import os.path
import dateutil.relativedelta
import calendar
import pandas as pd


# Settings
## Config
project = "project_opdi"
start_month = date(2022, 1, 1)
import_data = True


## Which months to process
today = date.today()
end_month = today - dateutil.relativedelta.relativedelta(months=1) # We work on the d-1 months

# Getting today's date formatted
today = today.strftime('%d %B %Y')

# Spark Session Initialization
#shutil.copy("/runtime-addons/cmladdon-2.0.40-b150/log4j.properties", "/etc/spark/conf/") # Setting logging properties
spark = SparkSession.builder \
    .appName("OPDI Ingestion") \
    .config("spark.log.level", "ERROR") \
    .config("spark.ui.showConsoleProgress", "false") \
    .config("spark.hadoop.fs.s3a.access.key", minio_access_key) \
    .config("spark.hadoop.fs.s3a.secret.key", minio_secret_key) \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.1") \
    .enableHiveSupport() \
    .getOrCreate()

from datetime import datetime, timedelta

def to_hour(timestamp):
    """Convert a Unix timestamp to an hour string (e.g., 'YYYY-MM-DD/HH')."""
    return datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d/%H')

def create_partition_paths(base_path, start_hour, num):
    """Generate partition paths for the given number of hours."""
    return [f"{base_path}/hour={to_hour(start_hour + i * 3600)}" for i in range(num)]

# Example usage
path = "https://s3.opensky-network.org"
hour = 1672531200  # Example Unix timestamp (Jan 1, 2023, 00:00:00 UTC)
num = 24  # Example: create 24-hour partitions

paths = create_partition_paths(path, hour, num)
df = spark.read.parquet("https://s3.opensky-network.org/ec-datadump/hour=2023-01-01/01")
# Out:
# Setting spark.hadoop.yarn.resourcemanager.principal to quinten.goens
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[1], line 57
#      54 num = 24  # Example: create 24-hour partitions
#      56 paths = create_partition_paths(path, hour, num)
# ---> 57 df = spark.read.parquet("https://s3.opensky-network.org/ec-datadump/hour=2023-01-01/01")
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/readwriter.py:364, in DataFrameReader.parquet(self, *paths, **options)
#     353 int96RebaseMode = options.get("int96RebaseMode", None)
#     354 self._set_opts(
#     355     mergeSchema=mergeSchema,
#     356     pathGlobFilter=pathGlobFilter,
#    (...)
#     361     int96RebaseMode=int96RebaseMode,
#     362 )
# --> 364 return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#
# ...
